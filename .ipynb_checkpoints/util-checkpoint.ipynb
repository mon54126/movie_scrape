# %%
import numpy as np
import pandas as pd
import datetime
import os
# ------- import ----------
from scrape_function import * 
from scrape_util import *

# %% [markdown]
# # combine df

# %%
home_movie = concat_df_from_dir('movies_at_home')

# %%
home_movie['platform'] = home_movie['date_list'].apply(lambda x:x.split()[0])
home_movie['movie_date'] = home_movie['date_list'].apply(lambda x:' '.join(x.split()[1:]))
home_movie['movie_date'] = pd.to_datetime(home_movie['movie_date'], format = '%b %d, %Y')
home_movie = home_movie[['title','critic_sentiment','critic_score','audience_setiment','audience_score','platform','movie_date']]
home_movie = home_movie

# %%
str_date = datetime(2020, 1, 1)
home_movie = home_movie[home_movie['movie_date'] > str_date]

# %%
home_movie
# Out:
#                             title critic_sentiment critic_score  \
# 1      Jailbreak: Love on the Run              NaN          NaN
# 12                    Inheritance         negative          24%
# 13                Spin the Bottle              NaN          NaN
# 16                      The Abyss              NaN          NaN
# 23                         Inside         positive          62%
# ...                           ...              ...          ...
# 20896           Code Name Banshee         negative           0%
# 20898               Crumb Catcher         positive          87%
# 20905             Force of Nature         negative           8%
# 20906   Four Hours at the Capitol         positive          89%
# 20909            Ginny Weds Sunny         negative          18%
#
#       audience_setiment audience_score   platform movie_date
# 1                   NaN            NaN  Streaming 2024-09-25
# 12             negative            26%  Streaming 2020-05-22
# 13                  NaN            NaN  Streaming 2024-10-04
# 16             negative            28%  Streaming 2024-02-16
# 23             negative            40%  Streaming 2023-04-04
# ...                 ...            ...        ...        ...
# 20896          positive            83%  Streaming 2022-07-01
# 20898          positive            85%  Streaming 2024-08-20
# 20905          negative            17%  Streaming 2020-06-30
# 20906          positive            62%  Streaming 2021-10-20
# 20909          positive            62%  Streaming 2020-10-09
#
# [6227 rows x 7 columns]

# %%
all_title = home_movie['title'].tolist()

# %% [markdown]
# # get review data from combined title

# %%
first_iter = True
istr = 0
istp = 500
for title in all_title[istr:istp]:
    try:
        if first_iter:
            df_review = get_movie_reviews(title)
            first_iter = False
        else:
            df_review_ = get_movie_reviews(title)
            df_review = pd.concat([df_review,df_review_], ignore_index = True) 
    except Exception as e:
        print(f'Failed to get review from {title}:  {e}')

df_review.to_csv(f'review_at_home/get_review_data_red_{istr}_{istp}.csv', index = False)
# Out:
# Scraping page1 of Jailbreak: Love on the Run
# C:\Users\User\Desktop\TUXSA\IS\scrape_function.py:150: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return df._append(df_to_append, ignore_index = True)
# Scraping page1 of Jailbreak: Love on the Run using start key = MQ
# False
# Scraping page1 of Inheritance
# Scraping page1 of Inheritance using start key = MQ
# False
# C:\Users\User\AppData\Local\Temp\ipykernel_3496\977685113.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_review = pd.concat([df_review,df_review_], ignore_index = True)
# Scraping page1 of Spin the Bottle
# Scraping page1 of Spin the Bottle using start key = MQ
# False
# Scraping page1 of The Abyss
# Scraping page1 of The Abyss using start key = MQ
# False
# Scraping page1 of Inside
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of Inside using start key = MQ
# False
# Scraping page1 of The Forgotten Battle
# Scraping page1 of The Forgotten Battle using start key = MQ
# False
# Scraping page1 of Unwrapping Christmas: Tina's Miracle
# Scraping page1 of The Book of Clarence
# Scraping page1 of The Book of Clarence using start key = MQ
# False
# Scraping page1 of The Unforgivable
# Scraping page1 of The Unforgivable using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Unforgivable using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Unforgivable using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Unforgivable using start key = NA
# False
# Scraping page1 of Retribution
# Scraping page1 of Retribution using start key = MQ
# False
# Scraping page1 of Wolfwalkers
# Scraping page1 of Wolfwalkers using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Wolfwalkers using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Wolfwalkers using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Wolfwalkers using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Wolfwalkers using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Wolfwalkers using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Wolfwalkers using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Wolfwalkers using start key = OA
# False
# Scraping page1 of Cash Out
# Scraping page1 of Cash Out using start key = MQ
# False
# Scraping page1 of Hell House LLC Origins: The Carmichael Manor
# Scraping page1 of Hell House LLC Origins: The Carmichael Manor using start key = MQ
# False
# Scraping page1 of Hellraiser
# Scraping page1 of Hellraiser using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Hellraiser using start key = Mg
# False
# Scraping page1 of Those Who Walk Away
# Scraping page1 of Those Who Walk Away using start key = MQ
# False
# Scraping page1 of Underwater
# Scraping page1 of Underwater using start key = MQ
# False
# Scraping page1 of After Yang
# Scraping page1 of After Yang using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of After Yang using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of After Yang using start key = Mw
# True
# Found next page token NA
# Scraping page4 of After Yang using start key = NA
# True
# Found next page token NQ
# Scraping page5 of After Yang using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of After Yang using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of After Yang using start key = Nw
# True
# Found next page token OA
# Scraping page8 of After Yang using start key = OA
# True
# Found next page token OQ
# Scraping page9 of After Yang using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of After Yang using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of After Yang using start key = MTE=
# False
# Scraping page1 of The Estate
# Scraping page1 of The Estate using start key = MQ
# False
# Scraping page1 of The Father
# Scraping page1 of The Father using start key = MQ
# False
# Scraping page1 of I Came By
# Scraping page1 of I Came By using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of I Came By using start key = Mg
# False
# Scraping page1 of The Many Saints of Newark
# Scraping page1 of The Many Saints of Newark using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Many Saints of Newark using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Many Saints of Newark using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Many Saints of Newark using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The Many Saints of Newark using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of The Many Saints of Newark using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of The Many Saints of Newark using start key = Nw
# True
# Found next page token OA
# Scraping page8 of The Many Saints of Newark using start key = OA
# True
# Found next page token OQ
# Scraping page9 of The Many Saints of Newark using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of The Many Saints of Newark using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of The Many Saints of Newark using start key = MTE=
# False
# Scraping page1 of The Contestant
# Scraping page1 of The Contestant using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Contestant using start key = Mg
# False
# Scraping page1 of Trolls Band Together
# Scraping page1 of Trolls Band Together using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Trolls Band Together using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Trolls Band Together using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Trolls Band Together using start key = NA
# False
# Scraping page1 of Good Grief
# Scraping page1 of Good Grief using start key = MQ
# False
# Scraping page1 of Old Henry
# Scraping page1 of Old Henry using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Old Henry using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Old Henry using start key = Mw
# False
# Scraping page1 of Happiness Is
# Scraping page1 of Happiness Is using start key = MQ
# False
# Scraping page1 of Next Goal Wins
# Scraping page1 of Next Goal Wins using start key = MQ
# False
# Scraping page1 of Vanished Into the Night
# Scraping page1 of Vanished Into the Night using start key = MQ
# False
# Scraping page1 of Luckiest Girl Alive
# Scraping page1 of Luckiest Girl Alive using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Luckiest Girl Alive using start key = Mg
# False
# Scraping page1 of Werewolf by Night
# Scraping page1 of Werewolf by Night using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Werewolf by Night using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Werewolf by Night using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Werewolf by Night using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Werewolf by Night using start key = NQ
# False
# Scraping page1 of Nanny
# Scraping page1 of Nanny using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Nanny using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Nanny using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Nanny using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Nanny using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Nanny using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Nanny using start key = Nw
# False
# Scraping page1 of Enola Holmes 2
# Scraping page1 of Enola Holmes 2 using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Enola Holmes 2 using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Enola Holmes 2 using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Enola Holmes 2 using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Enola Holmes 2 using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Enola Holmes 2 using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Enola Holmes 2 using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Enola Holmes 2 using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Enola Holmes 2 using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Enola Holmes 2 using start key = MTA=
# False
# Scraping page1 of Judas and the Black Messiah
# Scraping page1 of Judas and the Black Messiah using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Judas and the Black Messiah using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Judas and the Black Messiah using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Judas and the Black Messiah using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Judas and the Black Messiah using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Judas and the Black Messiah using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Judas and the Black Messiah using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Judas and the Black Messiah using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Judas and the Black Messiah using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Judas and the Black Messiah using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Judas and the Black Messiah using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Judas and the Black Messiah using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Judas and the Black Messiah using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Judas and the Black Messiah using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Judas and the Black Messiah using start key = MTU=
# True
# Found next page token MTY=
# Scraping page16 of Judas and the Black Messiah using start key = MTY=
# True
# Found next page token MTc=
# Scraping page17 of Judas and the Black Messiah using start key = MTc=
# False
# Scraping page1 of Till
# Scraping page1 of Till using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Till using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Till using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Till using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Till using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Till using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Till using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Till using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Till using start key = OQ
# False
# Scraping page1 of Blumhouse's Fantasy Island
# Scraping page1 of Nomadland
# Scraping page1 of Nomadland using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Nomadland using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Nomadland using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Nomadland using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Nomadland using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Nomadland using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Nomadland using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Nomadland using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Nomadland using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Nomadland using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Nomadland using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Nomadland using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Nomadland using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Nomadland using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Nomadland using start key = MTU=
# True
# Found next page token MTY=
# Scraping page16 of Nomadland using start key = MTY=
# True
# Found next page token MTc=
# Scraping page17 of Nomadland using start key = MTc=
# True
# Found next page token MTg=
# Scraping page18 of Nomadland using start key = MTg=
# True
# Found next page token MTk=
# Scraping page19 of Nomadland using start key = MTk=
# True
# Found next page token MjA=
# Scraping page20 of Nomadland using start key = MjA=
# True
# Found next page token MjE=
# Scraping page21 of Nomadland using start key = MjE=
# False
# Scraping page1 of Jeanne du Barry
# Scraping page1 of Jeanne du Barry using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Jeanne du Barry using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Jeanne du Barry using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Jeanne du Barry using start key = NA
# False
# Scraping page1 of The Ice Age Adventures of Buck Wild
# Scraping page1 of The Ice Age Adventures of Buck Wild using start key = MQ
# False
# Scraping page1 of Bros
# Scraping page1 of Bros using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Bros using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Bros using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Bros using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Bros using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Bros using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Bros using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Bros using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Bros using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Bros using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Bros using start key = MTE=
# False
# Scraping page1 of American Underdog
# Scraping page1 of American Underdog using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of American Underdog using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of American Underdog using start key = Mw
# False
# Scraping page1 of Breaking News in Yuba County
# Scraping page1 of Breaking News in Yuba County using start key = MQ
# False
# Scraping page1 of Paint
# Scraping page1 of Paint using start key = MQ
# False
# Scraping page1 of Dragon Ball Super: Super Hero
# Scraping page1 of Dragon Ball Super: Super Hero using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Dragon Ball Super: Super Hero using start key = Mg
# False
# Scraping page1 of Hard Miles
# Scraping page1 of Hard Miles using start key = MQ
# False
# Scraping page1 of Black Friday
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of Black Friday using start key = MQ
# False
# Scraping page1 of Jingle Jangle: A Christmas Journey
# Scraping page1 of Jingle Jangle: A Christmas Journey using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Jingle Jangle: A Christmas Journey using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Jingle Jangle: A Christmas Journey using start key = Mw
# False
# Scraping page1 of Huesera: The Bone Woman
# Scraping page1 of Huesera: The Bone Woman using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Huesera: The Bone Woman using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Huesera: The Bone Woman using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Huesera: The Bone Woman using start key = NA
# False
# Scraping page1 of Long Gone Heroes
# Scraping page1 of Long Gone Heroes using start key = MQ
# False
# Scraping page1 of Shadow in the Cloud
# Scraping page1 of Shadow in the Cloud using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Shadow in the Cloud using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Shadow in the Cloud using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Shadow in the Cloud using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Shadow in the Cloud using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Shadow in the Cloud using start key = Ng
# False
# Scraping page1 of The Half of It
# Scraping page1 of The Half of It using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Half of It using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Half of It using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Half of It using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The Half of It using start key = NQ
# False
# Scraping page1 of The Marsh King's Daughter
# Scraping page1 of I Used to be Funny
# Scraping page1 of I Used to be Funny using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of I Used to be Funny using start key = Mg
# False
# Scraping page1 of Living
# Scraping page1 of Living using start key = MQ
# False
# Scraping page1 of Emancipation
# Scraping page1 of Emancipation using start key = MQ
# False
# Scraping page1 of Chosen Family
# Scraping page1 of Chosen Family using start key = MQ
# False
# Scraping page1 of Flora and Son
# Scraping page1 of Flora and Son using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Flora and Son using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Flora and Son using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Flora and Son using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Flora and Son using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Flora and Son using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Flora and Son using start key = Nw
# False
# Scraping page1 of Possessor: Uncut
# Scraping page1 of Possessor: Uncut using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Possessor: Uncut using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Possessor: Uncut using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Possessor: Uncut using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Possessor: Uncut using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Possessor: Uncut using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Possessor: Uncut using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Possessor: Uncut using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Possessor: Uncut using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Possessor: Uncut using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Possessor: Uncut using start key = MTE=
# False
# Scraping page1 of Funny Games
# Scraping page1 of Sister Death
# Scraping page1 of Sister Death using start key = MQ
# False
# Scraping page1 of Hocus Pocus 2
# Scraping page1 of Hocus Pocus 2 using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Hocus Pocus 2 using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Hocus Pocus 2 using start key = Mw
# False
# Scraping page1 of The Man From Toronto
# Scraping page1 of The Man From Toronto using start key = MQ
# False
# Scraping page1 of Road Diary: Bruce Springsteen and The E Street Band
# Scraping page1 of Road Diary: Bruce Springsteen and The E Street Band using start key = MQ
# False
# Scraping page1 of The Old Oak
# Scraping page1 of The Old Oak using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Old Oak using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Old Oak using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Old Oak using start key = NA
# False
# Scraping page1 of Paris, 13th District
# Scraping page1 of Color Out of Space
# Scraping page1 of Color Out of Space using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Color Out of Space using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Color Out of Space using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Color Out of Space using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Color Out of Space using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Color Out of Space using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Color Out of Space using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Color Out of Space using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Color Out of Space using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Color Out of Space using start key = MTA=
# False
# Scraping page1 of Escape from Germany
# Scraping page1 of Escape from Germany using start key = MQ
# False
# Scraping page1 of Haunted Mansion
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of Haunted Mansion using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Haunted Mansion using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Haunted Mansion using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Haunted Mansion using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Haunted Mansion using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Haunted Mansion using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Haunted Mansion using start key = Nw
# False
# Scraping page1 of Persuasion
# Scraping page1 of Persuasion using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Persuasion using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Persuasion using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Persuasion using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Persuasion using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Persuasion using start key = Ng
# False
# Scraping page1 of Cry Macho
# Scraping page1 of Cry Macho using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Cry Macho using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Cry Macho using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Cry Macho using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Cry Macho using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Cry Macho using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Cry Macho using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Cry Macho using start key = OA
# False
# Scraping page1 of The Outlaws
# Scraping page1 of The Outlaws using start key = MQ
# False
# Scraping page1 of Ellen DeGeneres: For Your Approval
# Scraping page1 of Ellen DeGeneres: For Your Approval using start key = MQ
# False
# Scraping page1 of Silo
# Scraping page1 of Silo using start key = MQ
# False
# Scraping page1 of Space Jam: A New Legacy
# Scraping page1 of Space Jam: A New Legacy using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Space Jam: A New Legacy using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Space Jam: A New Legacy using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Space Jam: A New Legacy using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Space Jam: A New Legacy using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Space Jam: A New Legacy using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Space Jam: A New Legacy using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Space Jam: A New Legacy using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Space Jam: A New Legacy using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Space Jam: A New Legacy using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Space Jam: A New Legacy using start key = MTE=
# False
# Scraping page1 of Good Luck to You, Leo Grande
# Scraping page1 of Good Luck to You, Leo Grande using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Good Luck to You, Leo Grande using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Good Luck to You, Leo Grande using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Good Luck to You, Leo Grande using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Good Luck to You, Leo Grande using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Good Luck to You, Leo Grande using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Good Luck to You, Leo Grande using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Good Luck to You, Leo Grande using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Good Luck to You, Leo Grande using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Good Luck to You, Leo Grande using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Good Luck to You, Leo Grande using start key = MTE=
# False
# Scraping page1 of Onward
# Scraping page1 of Onward using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Onward using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Onward using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Onward using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Onward using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Onward using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Onward using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Onward using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Onward using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Onward using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Onward using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Onward using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Onward using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Onward using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Onward using start key = MTU=
# True
# Found next page token MTY=
# Scraping page16 of Onward using start key = MTY=
# True
# Found next page token MTc=
# Scraping page17 of Onward using start key = MTc=
# False
# Scraping page1 of Cuties
# Scraping page1 of Cuties using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Cuties using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Cuties using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Cuties using start key = NA
# False
# Scraping page1 of Baghead
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of Baghead using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Baghead using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Baghead using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Baghead using start key = NA
# False
# Scraping page1 of Expend4bles
# Scraping page1 of TAYLOR SWIFT | THE ERAS TOUR
# Scraping page1 of TAYLOR SWIFT | THE ERAS TOUR using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of TAYLOR SWIFT | THE ERAS TOUR using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of TAYLOR SWIFT | THE ERAS TOUR using start key = Mw
# True
# Found next page token NA
# Scraping page4 of TAYLOR SWIFT | THE ERAS TOUR using start key = NA
# False
# Scraping page1 of Miss Willoughby and the Haunted Bookshop
# Scraping page1 of Miss Willoughby and the Haunted Bookshop using start key = MQ
# False
# Scraping page1 of All the Bright Places
# Scraping page1 of All the Bright Places using start key = MQ
# False
# Scraping page1 of The Underdoggs
# Scraping page1 of The Underdoggs using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Underdoggs using start key = Mg
# False
# Scraping page1 of MILF
# Scraping page1 of MILF using start key = MQ
# False
# Scraping page1 of The Beasts
# Scraping page1 of The Beasts using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Beasts using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Beasts using start key = Mw
# False
# Scraping page1 of The Russian Girl
# Scraping page1 of The Russian Girl using start key = MQ
# False
# Scraping page1 of Blood for Dust
# Scraping page1 of Blood for Dust using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Blood for Dust using start key = Mg
# False
# Scraping page1 of A Rainy Day in New York
# Scraping page1 of A Rainy Day in New York using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of A Rainy Day in New York using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of A Rainy Day in New York using start key = Mw
# True
# Found next page token NA
# Scraping page4 of A Rainy Day in New York using start key = NA
# True
# Found next page token NQ
# Scraping page5 of A Rainy Day in New York using start key = NQ
# False
# Scraping page1 of Blood Red Sky
# Scraping page1 of Blood Red Sky using start key = MQ
# False
# Scraping page1 of Con Job
# Scraping page1 of Con Job using start key = MQ
# False
# Scraping page1 of Best. Christmas. Ever!
# Scraping page1 of Best. Christmas. Ever! using start key = MQ
# False
# Scraping page1 of Dog
# Scraping page1 of Dog using start key = MQ
# False
# Scraping page1 of A Thousand and One
# Scraping page1 of A Thousand and One using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of A Thousand and One using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of A Thousand and One using start key = Mw
# True
# Found next page token NA
# Scraping page4 of A Thousand and One using start key = NA
# True
# Found next page token NQ
# Scraping page5 of A Thousand and One using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of A Thousand and One using start key = Ng
# False
# Scraping page1 of Wendell & Wild
# Scraping page1 of Dragonkeeper
# Scraping page1 of Dragonkeeper using start key = MQ
# False
# Scraping page1 of Rebecca
# Scraping page1 of Rebecca using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Rebecca using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Rebecca using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Rebecca using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Rebecca using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Rebecca using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Rebecca using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Rebecca using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Rebecca using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Rebecca using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Rebecca using start key = MTE=
# False
# Scraping page1 of Johnny Puff: Secret Mission
# Scraping page1 of Johnny Puff: Secret Mission using start key = MQ
# False
# Scraping page1 of Justice League: Crisis on Infinite Earths Part One
# Scraping page1 of Justice League: Crisis on Infinite Earths Part One using start key = MQ
# False
# Scraping page1 of The Hitman's Wife's Bodyguard
# Scraping page1 of Champions
# Scraping page1 of Champions using start key = MQ
# False
# Scraping page1 of Descendants: The Rise of Red
# Scraping page1 of Descendants: The Rise of Red using start key = MQ
# False
# Scraping page1 of Rebel Moon - Part Two: Director's Cut
# Scraping page1 of American Dreamer
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of American Dreamer using start key = MQ
# False
# Scraping page1 of Green Border
# Scraping page1 of Green Border using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Green Border using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Green Border using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Green Border using start key = NA
# False
# Scraping page1 of Portraits
# Scraping page1 of Portraits using start key = MQ
# False
# Scraping page1 of The New Mutants
# Scraping page1 of The New Mutants using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The New Mutants using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The New Mutants using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The New Mutants using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The New Mutants using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of The New Mutants using start key = Ng
# False
# Scraping page1 of Fresh Kills
# Scraping page1 of Fresh Kills using start key = MQ
# False
# Scraping page1 of Nine Days
# Scraping page1 of Nine Days using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Nine Days using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Nine Days using start key = Mw
# Error getting review of id:d9bd46ef-1fb0-473d-91ef-9746de4a7045 on page3,   'endCursor'
# Scraping page1 of Ava
# Scraping page1 of Ava using start key = MQ
# False
# Scraping page1 of Raya and the Last Dragon
# Scraping page1 of Raya and the Last Dragon using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Raya and the Last Dragon using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Raya and the Last Dragon using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Raya and the Last Dragon using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Raya and the Last Dragon using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Raya and the Last Dragon using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Raya and the Last Dragon using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Raya and the Last Dragon using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Raya and the Last Dragon using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Raya and the Last Dragon using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Raya and the Last Dragon using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Raya and the Last Dragon using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Raya and the Last Dragon using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Raya and the Last Dragon using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Raya and the Last Dragon using start key = MTU=
# False
# Scraping page1 of After We Collided
# Scraping page1 of After We Collided using start key = MQ
# False
# Scraping page1 of Falling Stars
# Scraping page1 of Falling Stars using start key = MQ
# False
# Scraping page1 of Mother, Couch
# Scraping page1 of Mother, Couch using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Mother, Couch using start key = Mg
# False
# Scraping page1 of The Contractor
# Scraping page1 of What Happens Later
# Scraping page1 of What Happens Later using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of What Happens Later using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of What Happens Later using start key = Mw
# False
# Scraping page1 of Entergalactic
# Scraping page1 of Entergalactic using start key = MQ
# False
# Scraping page1 of Kimi
# Scraping page1 of Kimi using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Kimi using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Kimi using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Kimi using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Kimi using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Kimi using start key = Ng
# False
# Scraping page1 of Mayhem!
# Scraping page1 of Mayhem! using start key = MQ
# False
# Scraping page1 of The Imaginary
# Scraping page1 of The Imaginary using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Imaginary using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Imaginary using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Imaginary using start key = NA
# False
# Scraping page1 of The Next 365 Days
# Scraping page1 of Stowaway
# Scraping page1 of Players
# Scraping page1 of The Wonder
# Scraping page1 of The Wonder using start key = MQ
# False
# Scraping page1 of The Fabulous Four
# Scraping page1 of The Fabulous Four using start key = MQ
# False
# Scraping page1 of Boon
# Scraping page1 of Boon using start key = MQ
# False
# Scraping page1 of The School for Good and Evil
# Scraping page1 of The School for Good and Evil using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The School for Good and Evil using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The School for Good and Evil using start key = Mw
# False
# Scraping page1 of Hotel Transylvania: Transformania
# Scraping page1 of Hotel Transylvania: Transformania using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Hotel Transylvania: Transformania using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Hotel Transylvania: Transformania using start key = Mw
# False
# Scraping page1 of Fanatical: The Catfishing of Tegan and Sara
# Scraping page1 of Fanatical: The Catfishing of Tegan and Sara using start key = MQ
# False
# Scraping page1 of Uncorked
# Scraping page1 of Uncorked using start key = MQ
# False
# Scraping page1 of Burning Betrayal
# Scraping page1 of Burning Betrayal using start key = MQ
# False
# Scraping page1 of My Son
# Scraping page1 of My Son using start key = MQ
# False
# Scraping page1 of Dear Evan Hansen
# Scraping page1 of Dear Evan Hansen using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Dear Evan Hansen using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Dear Evan Hansen using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Dear Evan Hansen using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Dear Evan Hansen using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Dear Evan Hansen using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Dear Evan Hansen using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Dear Evan Hansen using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Dear Evan Hansen using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Dear Evan Hansen using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Dear Evan Hansen using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Dear Evan Hansen using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Dear Evan Hansen using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Dear Evan Hansen using start key = MTQ=
# False
# Scraping page1 of Rippy
# Scraping page1 of Rippy using start key = MQ
# False
# Scraping page1 of Stolen
# Scraping page1 of Stolen using start key = MQ
# False
# Scraping page1 of Home Sweet Home Alone
# Scraping page1 of Home Sweet Home Alone using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Home Sweet Home Alone using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Home Sweet Home Alone using start key = Mw
# False
# Scraping page1 of Jujutsu Kaisen 0: The Movie
# Scraping page1 of The White Tiger
# failed to get review text:list index out of range
# Scraping page1 of The White Tiger using start key = MQ
# False
# Scraping page1 of Strange World
# Scraping page1 of Strange World using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Strange World using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Strange World using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Strange World using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Strange World using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Strange World using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Strange World using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Strange World using start key = OA
# False
# Scraping page1 of Belfast
# Scraping page1 of Belfast using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Belfast using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Belfast using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Belfast using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Belfast using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Belfast using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Belfast using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Belfast using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Belfast using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Belfast using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Belfast using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Belfast using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Belfast using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Belfast using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Belfast using start key = MTU=
# True
# Found next page token MTY=
# Scraping page16 of Belfast using start key = MTY=
# False
# Scraping page1 of Devotion
# Scraping page1 of Devotion using start key = MQ
# False
# Scraping page1 of Influencer
# Scraping page1 of Influencer using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Influencer using start key = Mg
# False
# Scraping page1 of Lady Ballers
# Scraping page1 of Lady Ballers using start key = MQ
# False
# Scraping page1 of The Mauritanian
# Scraping page1 of The Mauritanian using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Mauritanian using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Mauritanian using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Mauritanian using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The Mauritanian using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of The Mauritanian using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of The Mauritanian using start key = Nw
# True
# Found next page token OA
# Scraping page8 of The Mauritanian using start key = OA
# True
# Found next page token OQ
# Scraping page9 of The Mauritanian using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of The Mauritanian using start key = MTA=
# False
# Scraping page1 of Whitney Houston: I Wanna Dance with Somebody
# Scraping page1 of Whitney Houston: I Wanna Dance with Somebody using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Whitney Houston: I Wanna Dance with Somebody using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Whitney Houston: I Wanna Dance with Somebody using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Whitney Houston: I Wanna Dance with Somebody using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Whitney Houston: I Wanna Dance with Somebody using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Whitney Houston: I Wanna Dance with Somebody using start key = Ng
# False
# Scraping page1 of The Midnight Sky
# Scraping page1 of The Midnight Sky using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Midnight Sky using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Midnight Sky using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Midnight Sky using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The Midnight Sky using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of The Midnight Sky using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of The Midnight Sky using start key = Nw
# True
# Found next page token OA
# Scraping page8 of The Midnight Sky using start key = OA
# True
# Found next page token OQ
# Scraping page9 of The Midnight Sky using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of The Midnight Sky using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of The Midnight Sky using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of The Midnight Sky using start key = MTI=
# False
# Scraping page1 of All That Breathes
# Scraping page1 of All That Breathes using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of All That Breathes using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of All That Breathes using start key = Mw
# True
# Found next page token NA
# Scraping page4 of All That Breathes using start key = NA
# False
# Scraping page1 of Sector 36
# Scraping page1 of Chicken Run: Dawn of the Nugget
# Scraping page1 of Chicken Run: Dawn of the Nugget using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Chicken Run: Dawn of the Nugget using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Chicken Run: Dawn of the Nugget using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Chicken Run: Dawn of the Nugget using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Chicken Run: Dawn of the Nugget using start key = NQ
# False
# Scraping page1 of Quantum Suicide
# Scraping page1 of Quantum Suicide using start key = MQ
# False
# Scraping page1 of The Blackening
# Scraping page1 of The Blackening using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Blackening using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Blackening using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Blackening using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The Blackening using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of The Blackening using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of The Blackening using start key = Nw
# False
# Scraping page1 of Swallowed
# Scraping page1 of Swallowed using start key = MQ
# False
# Scraping page1 of A Boy Called Christmas
# Scraping page1 of A Boy Called Christmas using start key = MQ
# False
# Scraping page1 of Femme
# Scraping page1 of Femme using start key = MQ
# False
# Scraping page1 of Romance
# Scraping page1 of Romance using start key = MQ
# False
# Scraping page1 of Spenser Confidential
# Scraping page1 of Spenser Confidential using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Spenser Confidential using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Spenser Confidential using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Spenser Confidential using start key = NA
# False
# Scraping page1 of The Mother
# Scraping page1 of The Mother using start key = MQ
# False
# Scraping page1 of Willy's Wonderland
# Scraping page1 of The Dry
# Scraping page1 of The Dry using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Dry using start key = Mg
# True
# Found next page token Mw
# ...
# True
# Found next page token OA
# Scraping page8 of Dolittle using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Dolittle using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Dolittle using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Dolittle using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Dolittle using start key = MTI=
# False
# Scraping page1 of In the Rearview
# Scraping page1 of In the Rearview using start key = MQ
# False
# Scraping page1 of Lost Girls
# Scraping page1 of Lost Girls using start key = MQ
# False
# Scraping page1 of The Last Letter From Your Lover
# Scraping page1 of The Last Letter From Your Lover using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Last Letter From Your Lover using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Last Letter From Your Lover using start key = Mw
# False
# Scraping page1 of Devil's Men
# Scraping page1 of Mr. Harrigan's Phone
# Scraping page1 of I.S.S.
# Scraping page1 of Maestro
# Scraping page1 of Maestro using start key = MQ
# False
# Scraping page1 of Army of Thieves
# Scraping page1 of Army of Thieves using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Army of Thieves using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Army of Thieves using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Army of Thieves using start key = NA
# False
# Scraping page1 of Camera
# Scraping page1 of Camera using start key = MQ
# False
# Scraping page1 of Before Dawn
# Scraping page1 of Before Dawn using start key = MQ
# False
# Scraping page1 of After Everything
# Scraping page1 of After Everything using start key = MQ
# False
# Scraping page1 of The Coffee Table
# Scraping page1 of The Coffee Table using start key = MQ
# False
# Scraping page1 of The Trial of the Chicago 7
# Scraping page1 of Hamilton
# Scraping page1 of Mickey and the Bear
# Scraping page1 of Mickey and the Bear using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Mickey and the Bear using start key = Mg
# False
# Scraping page1 of River Wild
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of River Wild using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of River Wild using start key = Mg
# False
# Scraping page1 of Minions: The Rise of Gru
# Scraping page1 of Minions: The Rise of Gru using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Minions: The Rise of Gru using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Minions: The Rise of Gru using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Minions: The Rise of Gru using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Minions: The Rise of Gru using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Minions: The Rise of Gru using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Minions: The Rise of Gru using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Minions: The Rise of Gru using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Minions: The Rise of Gru using start key = OQ
# False
# Scraping page1 of The Park Maniac
# Scraping page1 of The Park Maniac using start key = MQ
# False
# Scraping page1 of 100 Days to Live
# Scraping page1 of Mad God
# Scraping page1 of Mad God using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Mad God using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Mad God using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Mad God using start key = NA
# False
# Scraping page1 of I'm Thinking of Ending Things
# Scraping page1 of Haul Out the Holly
# Scraping page1 of Haul Out the Holly using start key = MQ
# False
# Scraping page1 of Luther: The Fallen Sun
# Scraping page1 of Luther: The Fallen Sun using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Luther: The Fallen Sun using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Luther: The Fallen Sun using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Luther: The Fallen Sun using start key = NA
# False
# Scraping page1 of Lightyear
# Scraping page1 of Lightyear using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Lightyear using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Lightyear using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Lightyear using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Lightyear using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Lightyear using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Lightyear using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Lightyear using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Lightyear using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Lightyear using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Lightyear using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Lightyear using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Lightyear using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Lightyear using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Lightyear using start key = MTU=
# True
# Found next page token MTY=
# Scraping page16 of Lightyear using start key = MTY=
# False
# Scraping page1 of Space Cadet
# Scraping page1 of Space Cadet using start key = MQ
# False
# Scraping page1 of The Other Zoey
# Scraping page1 of The Other Zoey using start key = MQ
# False
# Scraping page1 of Your Place or Mine
# Scraping page1 of Your Place or Mine using start key = MQ
# False
# Scraping page1 of Blood Quantum
# Scraping page1 of Blood Quantum using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Blood Quantum using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Blood Quantum using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Blood Quantum using start key = NA
# False
# Scraping page1 of Holidate
# Scraping page1 of Holidate using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Holidate using start key = Mg
# False
# Scraping page1 of Take Cover
# Scraping page1 of Take Cover using start key = MQ
# False
# Scraping page1 of The Sadness
# Scraping page1 of The Sadness using start key = MQ
# False
# Scraping page1 of Fitting In
# Scraping page1 of Fitting In using start key = MQ
# False
# Scraping page1 of Mea Culpa
# Scraping page1 of Mea Culpa using start key = MQ
# False
# Scraping page1 of Roald Dahl's The Witches
# Scraping page1 of Tick, Tick... Boom!
# Scraping page1 of Tick, Tick... Boom! using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Tick, Tick... Boom! using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Tick, Tick... Boom! using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Tick, Tick... Boom! using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Tick, Tick... Boom! using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Tick, Tick... Boom! using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Tick, Tick... Boom! using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Tick, Tick... Boom! using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Tick, Tick... Boom! using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Tick, Tick... Boom! using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Tick, Tick... Boom! using start key = MTE=
# False
# Scraping page1 of The Informer
# Scraping page1 of The Informer using start key = MQ
# False
# Scraping page1 of Causeway
# Scraping page1 of Causeway using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Causeway using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Causeway using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Causeway using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Causeway using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Causeway using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Causeway using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Causeway using start key = OA
# False
# Scraping page1 of Fast Charlie
# Scraping page1 of Fast Charlie using start key = MQ
# False
# Scraping page1 of The Diary
# Scraping page1 of V/H/S/94
# Scraping page1 of Cha Cha Real Smooth
# Scraping page1 of Cha Cha Real Smooth using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Cha Cha Real Smooth using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Cha Cha Real Smooth using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Cha Cha Real Smooth using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Cha Cha Real Smooth using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Cha Cha Real Smooth using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Cha Cha Real Smooth using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Cha Cha Real Smooth using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Cha Cha Real Smooth using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Cha Cha Real Smooth using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Cha Cha Real Smooth using start key = MTE=
# False
# Scraping page1 of Coming Home in the Dark
# Scraping page1 of Coming Home in the Dark using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Coming Home in the Dark using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Coming Home in the Dark using start key = Mw
# False
# Scraping page1 of Significant Other
# Scraping page1 of Significant Other using start key = MQ
# False
# Scraping page1 of Drive My Car
# Scraping page1 of Drive My Car using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Drive My Car using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Drive My Car using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Drive My Car using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Drive My Car using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Drive My Car using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Drive My Car using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Drive My Car using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Drive My Car using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Drive My Car using start key = MTA=
# False
# Scraping page1 of The Lodge
# Scraping page1 of The Lodge using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Lodge using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of The Lodge using start key = Mw
# True
# Found next page token NA
# Scraping page4 of The Lodge using start key = NA
# True
# Found next page token NQ
# Scraping page5 of The Lodge using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of The Lodge using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of The Lodge using start key = Nw
# True
# Found next page token OA
# Scraping page8 of The Lodge using start key = OA
# True
# Found next page token OQ
# Scraping page9 of The Lodge using start key = OQ
# False
# Scraping page1 of Coup!
# Scraping page1 of Coup! using start key = MQ
# False
# Scraping page1 of Jungle Cruise
# Scraping page1 of Jungle Cruise using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Jungle Cruise using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Jungle Cruise using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Jungle Cruise using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Jungle Cruise using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Jungle Cruise using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Jungle Cruise using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Jungle Cruise using start key = OA
# True
# Found next page token OQ
# Scraping page9 of Jungle Cruise using start key = OQ
# True
# Found next page token MTA=
# Scraping page10 of Jungle Cruise using start key = MTA=
# True
# Found next page token MTE=
# Scraping page11 of Jungle Cruise using start key = MTE=
# True
# Found next page token MTI=
# Scraping page12 of Jungle Cruise using start key = MTI=
# True
# Found next page token MTM=
# Scraping page13 of Jungle Cruise using start key = MTM=
# True
# Found next page token MTQ=
# Scraping page14 of Jungle Cruise using start key = MTQ=
# True
# Found next page token MTU=
# Scraping page15 of Jungle Cruise using start key = MTU=
# True
# Found next page token MTY=
# Scraping page16 of Jungle Cruise using start key = MTY=
# True
# Found next page token MTc=
# Scraping page17 of Jungle Cruise using start key = MTc=
# False
# Scraping page1 of The Curse of the Necklace
# Scraping page1 of The Curse of the Necklace using start key = MQ
# False
# Scraping page1 of The Wrong Missy
# Scraping page1 of The Wrong Missy using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of The Wrong Missy using start key = Mg
# False
# Scraping page1 of Weird: The Al Yankovic Story
# Scraping page1 of Weird: The Al Yankovic Story using start key = MQ
# True
# Found next page token Mg
# Scraping page2 of Weird: The Al Yankovic Story using start key = Mg
# True
# Found next page token Mw
# Scraping page3 of Weird: The Al Yankovic Story using start key = Mw
# True
# Found next page token NA
# Scraping page4 of Weird: The Al Yankovic Story using start key = NA
# True
# Found next page token NQ
# Scraping page5 of Weird: The Al Yankovic Story using start key = NQ
# True
# Found next page token Ng
# Scraping page6 of Weird: The Al Yankovic Story using start key = Ng
# True
# Found next page token Nw
# Scraping page7 of Weird: The Al Yankovic Story using start key = Nw
# True
# Found next page token OA
# Scraping page8 of Weird: The Al Yankovic Story using start key = OA
# False
# Scraping page1 of Heretic
# Scraping page1 of Heretic using start key = MQ
# False
# Scraping page1 of Invitation to a Murder
# Scraping page1 of Invitation to a Murder using start key = MQ
# False
# Scraping page1 of Love Again
# Scraping page1 of Love Again using start key = MQ
# False
# Scraping page1 of 8-Bit Christmas
# Scraping page1 of Lie With Me
# Scraping page1 of Lie With Me using start key = MQ
# False
# Scraping page1 of Luck
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of Luck using start key = MQ
# False
# Scraping page1 of The Call of the Wild
# Scraping page1 of The Call of the Wild using start key = MQ
# False
# Scraping page1 of Place of Bones
# Scraping page1 of Place of Bones using start key = MQ
# False
# Scraping page1 of Jailbreak: Love on the Run
# Scraping page1 of Jailbreak: Love on the Run using start key = MQ
# False
# Scraping page1 of Inheritance
# Scraping page1 of Inheritance using start key = MQ
# False
# Scraping page1 of Spin the Bottle
# Scraping page1 of Spin the Bottle using start key = MQ
# False
# Scraping page1 of The Abyss
# Scraping page1 of The Abyss using start key = MQ
# False
# Scraping page1 of Inside
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# failed to get review text:list index out of range
# Scraping page1 of Inside using start key = MQ
# False
# Scraping page1 of The Forgotten Battle
# Scraping page1 of The Forgotten Battle using start key = MQ
# False
# Scraping page1 of Unwrapping Christmas: Tina's Miracle

# %%
len(all_title)
# Out:
# 6227

# %%
df_review
# Out:
#                       movie_title                              movie_id  \
# 0      Jailbreak: Love on the Run  4105633c-3c18-4ecd-bf60-196acdd7b16b
# 1      Jailbreak: Love on the Run  4105633c-3c18-4ecd-bf60-196acdd7b16b
# 2                       The Abyss  683563c4-388d-3b0a-a899-eb4333d9c572
# 3                       The Abyss  683563c4-388d-3b0a-a899-eb4333d9c572
# 4                       The Abyss  683563c4-388d-3b0a-a899-eb4333d9c572
# ...                           ...                                   ...
# 26158        The Forgotten Battle  09863b87-a53d-31e0-a1af-99f7293b9461
# 26159        The Forgotten Battle  09863b87-a53d-31e0-a1af-99f7293b9461
# 26160        The Forgotten Battle  09863b87-a53d-31e0-a1af-99f7293b9461
# 26161        The Forgotten Battle  09863b87-a53d-31e0-a1af-99f7293b9461
# 26162        The Forgotten Battle  09863b87-a53d-31e0-a1af-99f7293b9461
#
#          reviewer_name review_date review_score review_sentiment  \
# 0         Nick Schager  2024-09-25    Not found         POSITIVE
# 1       Archi Sengupta  2024-09-25          4/5         POSITIVE
# 2           Jose Solís  2024-03-13    Not found         POSITIVE
# 3         John O'Brien  2024-02-21    Not found         POSITIVE
# 4           John Serba  2024-02-20    Not found         POSITIVE
# ...                ...         ...          ...              ...
# 26158    Frank Wilkins  2021-11-12          5/5         POSITIVE
# 26159   Graeme Tuckett  2021-10-29    Not found         POSITIVE
# 26160         JK Sooja  2021-10-27          4/5         POSITIVE
# 26161  Pablo O. Scholz  2021-10-25    Not found         POSITIVE
# 26162    Johnny Loftus  2021-10-19    Not found         POSITIVE
#
#                                              review_text  on_page
# 0      Flails in trying to cast itself as a heartenin...      1.0
# 1      'Jailbreak: Love on the Run' is a fascinating ...      1.0
# 2      For the rest of us, The Abyss plays very much ...      1.0
# 3      For those who prefer their disaster flicks wit...      1.0
# 4      The application of a little verisimilitude hel...      1.0
# ...                                                  ...      ...
# 26158  Sure to satisfy history buffs as well as fans ...      1.0
# 26159  If you've been missing a spectacular but uncom...      1.0
# 26160  Unflinching, brutal, terrifying, sad, and gut-...      1.0
# 26161  There's careful work in the combat scenes' ela...      1.0
# 26162  The Forgotten Battle approaches the scope of a...      1.0
#
# [26163 rows x 8 columns]
