# %%
import numpy as np
import pandas as pd
import datetime
import os
# ------- import ----------
from scrape_function import * 
from scrape_util import *

# %% [markdown]
# # combine df

# %%
home_movie = concat_df_from_dir('movies_at_home')

# %%
all_title = home_movie['title'].tolist()

# %% [markdown]
# # get review data from combined title

# %%
df_review = None
for title in all_title:
    if df_review:
        df_review = df_review._append(df_review, ignore_index = True)
    df_review = get_movie_reviews(title)

# %%
x = get_movie_reviews(all_title[0])
# Out:
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Scraping page1 of Freddy vs. Jason
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# C:\Users\User\Desktop\TUXSA\IS\scrape_function.py:134: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return df._append(df_to_append, ignore_index = True)
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Try to get response from https://www.rottentomatoes.com/m/freddy_vs_jason/reviews
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=MQ%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = MQ
# True
# Found next page token Mg
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=Mg%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = Mg
# True
# Found next page token Mw
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=Mw%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = Mw
# True
# Found next page token NA
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=NA%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = NA
# True
# Found next page token NQ
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=NQ%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = NQ
# True
# Found next page token Ng
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=Ng%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = Ng
# True
# Found next page token Nw
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=Nw%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = Nw
# True
# Found next page token OA
# Using url:https://www.rottentomatoes.com/napi/movie/4b43a104-8864-3a9b-bc0d-284ec1d6bcc0/reviews/all?after=OA%3D%3D&pageCount=20
# Scraping page2 of Freddy vs. Jason using start key = OA
# False

# %%
x
# Out:
#           movie_title                              movie_id  \
# 0    Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 1    Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 2    Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 3    Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 4    Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# ..                ...                                   ...
# 159  Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 160  Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 161  Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 162  Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
# 163  Freddy vs. Jason  4b43a104-8864-3a9b-bc0d-284ec1d6bcc0
#
#             reviewer_name review_date review_score review_sentiment  \
# 0            Matt Brunson  2024-10-20          2/4         NEGATIVE
# 1        Cassondra Feltus  2023-10-13          3/5         POSITIVE
# 2        Keith Garlington  2023-08-11          2/5         NEGATIVE
# 3              Jae-Ha Kim  2023-07-26        1.5/4         NEGATIVE
# 4             James Croot  2023-06-21        2.5/5         NEGATIVE
# ..                    ...         ...          ...              ...
# 159  Michael Rechtshaffen  2003-08-11                      NEGATIVE
# 160         Brian Webster  2003-08-09       61/100         NEGATIVE
# 161        Matthew Turner  2003-08-09          3/5         POSITIVE
# 162           Ed Gonzalez  2003-08-07        1.5/4         NEGATIVE
# 163            Rich Cline  2003-07-31          3/5         POSITIVE
#
#                                            review_text  on_page
# 0    It manages to combine two durable franchises i...      1.0
# 1    Freddy vs. Jason is an early-aughts slasher wi...      1.0
# 2    It leans too heavily on the worst elements of ...      1.0
# 3    We're not supposed to tell you who the ultimat...      1.0
# 4    Freddy vs Jason was a solid entry in the Frida...      1.0
# ..                                                 ...      ...
# 159  Witless, excessive and ultimately boring gore-...      2.0
# 160  Like the later chapters in both of these seemi...      2.0
# 161  Entertaining, extremely gory horror flick that...      2.0
# 162  More clever than your average Friday the 13th ...      2.0
# 163  A lively concoction of genre in-jokes with ele...      2.0
#
# [164 rows x 8 columns]
