# %%
from bs4 import BeautifulSoup
from requests import TooManyRedirects
import re
import requests
from datetime import datetime
import os
import pandas as pd
import regex as re

# %%
home_movie = concat_df_from_dir('movies_at_home')
home_movie['platform'] = home_movie['date_list'].apply(lambda x:x.split()[0])
home_movie['movie_date'] = home_movie['date_list'].apply(lambda x:' '.join(x.split()[1:]))
home_movie['movie_date'] = pd.to_datetime(home_movie['movie_date'], format = '%b %d, %Y')
home_movie = home_movie[['title','critic_sentiment','critic_score','audience_setiment','audience_score','platform','movie_date']]
home_movie = home_movie
str_date = datetime(2020, 1, 1)
home_movie = home_movie[home_movie['movie_date'] > str_date]
all_title = home_movie['title'].tolist()

# %%
def get_movie_info(movie_name):
    #movie_name = 'Hocus Pocus'
    movie_name = re.sub(r"[^a-zA-Z]{1,}", "_", movie_name).lower()
    if movie_name[-1] == '_':
        movie_name = movie_name[:-1]
    print(f'Try to get response from https://www.rottentomatoes.com/m/{movie_name}')
    response = requests.get(f'https://www.rottentomatoes.com/m/{movie_name}')
    soup = BeautifulSoup(response.content, 'html.parser')
    #<div class="category-wrap" data-qa="item">
    content_wrap = soup.find_all('div',class_ = 'category-wrap', attrs={"data-qa": "item"})
    for _ in content_wrap:
        k = ','.join([x.contents[0] for x in _.find_all(attrs={"data-qa": "item-label"})])
        v = [','.join([x.contents[0] for x in _.find_all(attrs={"data-qa": "item-value"})])]
        d[k] = v
    return pd.DataFrame(d)

# %%
first_iter = True
istr = 0
istp = 1000
for title in all_title[istr:istp]:
    try:
        if first_iter:
            df = get_movie_info(title)
            df['title'] = title
            first_iter = False
        else:
            df_ = get_movie_info(title)
            df_['title'] = title
        df = df._append(df_, ignore_index = True)
    except Exception as e:
        print(f'Failed to get review from {title}:  {e}')
df.to_csv(f'movie_info/movie_info_{istr}_{istp}.csv', index = False)
# Out:
# Try to get response from https://www.rottentomatoes.com/m/jailbreak_love_on_the_run
# Try to get response from https://www.rottentomatoes.com/m/inheritance
# Try to get response from https://www.rottentomatoes.com/m/spin_the_bottle
# Try to get response from https://www.rottentomatoes.com/m/the_abyss
# Try to get response from https://www.rottentomatoes.com/m/inside
# Try to get response from https://www.rottentomatoes.com/m/the_forgotten_battle
# Try to get response from https://www.rottentomatoes.com/m/unwrapping_christmas_tina_s_miracle
# Try to get response from https://www.rottentomatoes.com/m/the_book_of_clarence
# Try to get response from https://www.rottentomatoes.com/m/the_unforgivable
# Try to get response from https://www.rottentomatoes.com/m/retribution

# %%
df
# Out:
#       Distributor                            Genre Original Language  \
# 0         Netflix                Crime,Documentary           English
# 1         Netflix   Mystery & Thriller,Crime,Drama           English
# 2         Netflix                            Drama           English
# 3         Netflix                   Romance,Comedy           English
# 4         Netflix  Action,Drama,Mystery & Thriller           Swedish
# 5         Netflix               Mystery & Thriller           English
# 6   Epic Pictures                            Drama             Dutch
# 7   Epic Pictures                            Drama             Dutch
# 8   Epic Pictures                      Documentary           English
# 9         Netflix                            Drama           English
# 10        Netflix   Mystery & Thriller,Crime,Drama           English
#
#    Release Date (Streaming) Runtime                     Director  \
# 0              Sep 25, 2024  1h 28m            Alexander Pineiro
# 1              Dec 10, 2021     11m            Alexander Pineiro
# 2               Jun 5, 2017  1h 36m                   Bobby Roth
# 3              Jan 16, 2018  1h 37m        Michael Andrew Pascal
# 4              Feb 16, 2024  1h 43m                 Richard Holm
# 5              Feb 16, 2024  1h 39m                  Jeff Mahler
# 6              Oct 15, 2021   2h 4m  Matthijs van Heijningen Jr.
# 7              Oct 15, 2021   2h 4m  Matthijs van Heijningen Jr.
# 8              Oct 15, 2021   2h 0m                   Lee Breuer
# 9              Dec 10, 2021  1h 52m             Nora Fingscheidt
# 10             Dec 10, 2021     11m            Alexander Pineiro
#
#                                       Producer  \
# 0                             Jetaun Maldonado
# 1                             Jetaun Maldonado
# 2                                   Edwin Self
# 3                                   Edwin Self
# 4                               Joakim Hansson
# 5                                  Jeff Mahler
# 6                              Alain De Levita
# 7                              Alain De Levita
# 8              Samuel Butler Jr.,Eric Marciano
# 9   Sandra Bullock,Veronica Ferres,Graham King
# 10                            Jetaun Maldonado
#
#                                         Production Co  \
# 0             Construction Film,GK Films,Fortis Films
# 1             Construction Film,GK Films,Fortis Films
# 2   Alliance Atlantis Communications,Cosgrove/Meur...
# 3   Alliance Atlantis Communications,Cosgrove/Meur...
# 4                SF Studios,Mjölk Movies,Film Tampere
# 5                SF Studios,Mjölk Movies,Film Tampere
# 6   Levitate Film,Evangelische Omroep,Caviar Film ...
# 7   Levitate Film,Evangelische Omroep,Caviar Film ...
# 8   Levitate Film,Evangelische Omroep,Caviar Film ...
# 9             Construction Film,GK Films,Fortis Films
# 10            Construction Film,GK Films,Fortis Films
#
#                        Rating                               Screenwriter  \
# 0   R (Language and Violence)                          Alexander Pineiro
# 1   R (Language and Violence)                          Alexander Pineiro
# 2                        TV-G                          Alexander Pineiro
# 3                        TV-G                          Alexander Pineiro
# 4                        TV-G                               Richard Holm
# 5                        TV-G                                Jeff Mahler
# 6                        TV-G                         Paula van der Oest
# 7                        TV-G                         Paula van der Oest
# 8                        TV-G                   Lee Breuer,Eric Marciano
# 9   R (Language and Violence)  Peter Craig,Hillary Seitz,Courtenay Miles
# 10  R (Language and Violence)                          Alexander Pineiro
#
#    Release Date (DVD) Release Date (Theaters)      Sound Mix  \
# 0        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 1        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 2        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 3        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 4        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 5        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 6        Jan 23, 2007    Aug 2, 2024, Limited  Dolby Digital
# 7        Jan 23, 2007    Aug 2, 2024, Limited  Dolby Digital
# 8        Jan 23, 2007    Aug 2, 2024, Limited  Dolby Digital
# 9        Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
# 10       Jan 23, 2007   Nov 24, 2021, Limited  Dolby Digital
#
#                                    title
# 0             Jailbreak: Love on the Run
# 1                            Retribution
# 2                            Inheritance
# 3                        Spin the Bottle
# 4                              The Abyss
# 5                                 Inside
# 6                   The Forgotten Battle
# 7   Unwrapping Christmas: Tina's Miracle
# 8                   The Book of Clarence
# 9                       The Unforgivable
# 10                           Retribution

# %%
all_title[:10]
# Out:
# ['Jailbreak: Love on the Run',
#  'Inheritance',
#  'Spin the Bottle',
#  'The Abyss',
#  'Inside',
#  'The Forgotten Battle',
#  "Unwrapping Christmas: Tina's Miracle",
#  'The Book of Clarence',
#  'The Unforgivable',
#  'Retribution']
